# %%
from src.financial_data import FinancialData

# %%
fin_data = FinancialData()

# %%
# list the tickers
"""
Default is set to a polars dataframe
"""
fin_data.list_tickers()
# Out:
# shape: (1_868, 8)
# ┌────────┬─────────────┬─────────────┬─────────┬──────────┬─────────────┬─────────────┬────────────┐
# │ Symbol ┆ Name        ┆ Market Cap  ┆ Country ┆ IPO Year ┆ Sector      ┆ Industry    ┆ Market Cap │
# │ ---    ┆ ---         ┆ ---         ┆ ---     ┆ ---      ┆ ---         ┆ ---         ┆ Name       │
# │ str    ┆ str         ┆ f64         ┆ str     ┆ i64      ┆ str         ┆ str         ┆ ---        │
# │        ┆             ┆             ┆         ┆          ┆             ┆             ┆ str        │
# ╞════════╪═════════════╪═════════════╪═════════╪══════════╪═════════════╪═════════════╪════════════╡
# │ AACG   ┆ ATA         ┆ 2.6691308e7 ┆ China   ┆ 2008     ┆ Real Estate ┆ Other       ┆ Nano       │
# │        ┆ Creativity  ┆             ┆         ┆          ┆             ┆ Consumer    ┆            │
# │        ┆ Global      ┆             ┆         ┆          ┆             ┆ Services    ┆            │
# ...

# %%
# list the tickers as a dataframe
"""
Set the parameter as_pandas to True if you want to work with a pandas dataframe
"""
fin_data.list_tickers(as_pandas=True)
# Out:
#      Symbol                                              Name    Market Cap  \
# 0      AACG  ATA Creativity Global American Depositary Shares  2.669131e+07
# 1       AAL         American Airlines Group Inc. Common Stock  7.505250e+09
# 2      AAOI         Applied Optoelectronics Inc. Common Stock  9.348115e+08
# 3       AAP                           Advance Auto Parts Inc.  2.980102e+09
# 4      AAPL                           Apple Inc. Common Stock  3.045714e+12
# ...     ...                                               ...           ...
# 1863     ZM     Zoom Communications Inc. Class A Common Stock  2.430970e+10
# 1864     ZS                         Zscaler Inc. Common Stock  4.718046e+10
# 1865   ZSPC                          zSpace Inc. Common stock  1.047981e+08
# 1866   ZUMZ                          Zumiez Inc. Common Stock  2.320181e+08
# 1867   ZVIA                    Zevia PBC Class A Common Stock  1.974285e+08
#
#             Country  IPO Year                  Sector  \
# ...

# %%
# pull the balance sheet data
"""
Set the parameter as_pandas to True if you want to work with a pandas dataframe. Same goes for income and cashflows
"""
ticker = 'AEM'
fin_data.get_balance_sheet(ticker=ticker)
# Out:
# shape: (81, 38)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ fiscalDat ┆ reportedC ┆ totalAsse ┆ totalCurr ┆ … ┆ treasuryS ┆ retainedE ┆ commonSto ┆ commonSt │
# │ eEnding   ┆ urrency   ┆ ts        ┆ entAssets ┆   ┆ tock      ┆ arnings   ┆ ck        ┆ ockShare │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ sOutstan │
# │ str       ┆ str       ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ ding     │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2024-09-3 ┆ USD       ┆ 2.9769e10 ┆ 2.9077e9  ┆ … ┆ null      ┆ 1.7246e9  ┆ 1.8663e10 ┆ 5.02106e │
# ...

# %%
fin_data.get_income_statement(ticker=ticker)
# Out:
# shape: (81, 26)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ fiscalDat ┆ reportedC ┆ grossProf ┆ totalReve ┆ … ┆ comprehen ┆ ebit      ┆ ebitda    ┆ netIncom │
# │ eEnding   ┆ urrency   ┆ it        ┆ nue       ┆   ┆ siveIncom ┆ ---       ┆ ---       ┆ e        │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ eNetOfTax ┆ f64       ┆ f64       ┆ ---      │
# │ str       ┆ str       ┆ f64       ┆ f64       ┆   ┆ ---       ┆           ┆           ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆ f64       ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2004-09-3 ┆ USD       ┆ 2.2064e7  ┆ 4.8045e7  ┆ … ┆ null      ┆ 1.3765e7  ┆ 2.0485e7  ┆ 1.0556e7 │
# │ 0         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# ...

# %%
fin_data.get_cash_flow(ticker=ticker)
# Out:
# shape: (81, 29)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ fiscalDat ┆ reportedC ┆ operating ┆ paymentsF ┆ … ┆ proceedsF ┆ changeInC ┆ changeInE ┆ netIncom │
# │ eEnding   ┆ urrency   ┆ Cashflow  ┆ orOperati ┆   ┆ romSaleOf ┆ ashAndCas ┆ xchangeRa ┆ e        │
# │ ---       ┆ ---       ┆ ---       ┆ ngActivit ┆   ┆ TreasuryS ┆ hEquivale ┆ te        ┆ ---      │
# │ str       ┆ str       ┆ f64       ┆ ies       ┆   ┆ toc…      ┆ nts       ┆ ---       ┆ f64      │
# │           ┆           ┆           ┆ ---       ┆   ┆ ---       ┆ ---       ┆ f64       ┆          │
# │           ┆           ┆           ┆ f64       ┆   ┆ f64       ┆ f64       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2024-09-3 ┆ USD       ┆ 1.0891e9  ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ 5.716799 │
# ...

# %%
fin_data.get_historical_stock_prices(ticker=ticker)
# Out:
# shape: (13_343, 7)
# ┌────────────┬────────────┬────────────┬────────────┬─────────┬───────────┬──────────────┐
# │ Open       ┆ High       ┆ Low        ┆ Close      ┆ Volume  ┆ Dividends ┆ Stock Splits │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---     ┆ ---       ┆ ---          │
# │ f64        ┆ f64        ┆ f64        ┆ f64        ┆ i64     ┆ f64       ┆ f64          │
# ╞════════════╪════════════╪════════════╪════════════╪═════════╪═══════════╪══════════════╡
# │ 2.620078   ┆ 2.620078   ┆ 2.620078   ┆ 2.620078   ┆ 22600   ┆ 0.0       ┆ 0.0          │
# │ 2.620078   ┆ 2.620078   ┆ 2.620078   ┆ 2.620078   ┆ 56100   ┆ 0.0       ┆ 0.0          │
# │ 2.620078   ┆ 2.620078   ┆ 2.620078   ┆ 2.620078   ┆ 42200   ┆ 0.0       ┆ 0.0          │
# │ 2.535558   ┆ 2.535558   ┆ 2.535558   ┆ 2.535558   ┆ 30300   ┆ 0.0       ┆ 0.0          │
# │ 2.535558   ┆ 2.535558   ┆ 2.535558   ┆ 2.535558   ┆ 16300   ┆ 0.0       ┆ 0.0          │
# ...
